# %% [markdown]
# <a href="https://colab.research.google.com/github/kdemertzis/R2D2/blob/main/r2d2-final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ipywidgets
# !pip install scikit-fuzzy
# !pip install ipywidgets[tabulator]
# !pip install qgrid
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# WARNING: ipywidgets 7.7.1 does not provide the extra 'tabulator'
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 889.2/889.2 KB 18.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for qgrid: filename=qgrid-1.3.1-py2.py3-none-any.whl size=1761270 sha256=db287d96317a79ff7d2f6d589d9ad3299e0d5be1f5865d6b9045335a0640ba03
#   Stored in directory: /root/.cache/pip/wheels/65/29/13/1def97680a393587b2a731261dbef083633a1586fbd785446e
# Successfully built qgrid
# ...

# %%
import requests
import json
import datetime

# Replace with appropriate CVE IDs for the threats you're analyzing
cve_ids = ["CVE-2022-34878", "CVE-2022-35414"]

def fetch_cvss_scores(cve_ids):
    base_url = "https://services.nvd.nist.gov/rest/json/cve/1.0/"
    cvss_scores = {}

    for cve_id in cve_ids:
        url = f"{base_url}{cve_id}"
        response = requests.get(url)

        if response.status_code == 200:
            data = json.loads(response.text)
            cvss_v3 = data["result"]["CVE_Items"][0]["impact"]["baseMetricV3"]["cvssV3"]["baseScore"]
            cvss_scores[cve_id] = cvss_v3
        else:
            print(f"Error fetching data for {cve_id}")

    return cvss_scores

def calculate_threat_probability(cvss_scores, threat_frequencies):
    weighted_scores = {}
    for cve_id in cvss_scores:
        weighted_scores[cve_id] = cvss_scores[cve_id] * threat_frequencies[cve_id]

    return weighted_scores

if __name__ == "__main__":
    cvss_scores = fetch_cvss_scores(cve_ids)
    print("CVSS Scores:", cvss_scores)

    # Replace with appropriate threat frequencies for your application
    threat_frequencies = {
        "CVE-2022-34878": 4,
        "CVE-2022-35414": 6,
    }

    weighted_scores = calculate_threat_probability(cvss_scores, threat_frequencies)
    print("Weighted Threat Probabilities:", weighted_scores)
# Out:
# CVSS Scores: {'CVE-2022-34878': 8.8, 'CVE-2022-35414': 8.8}
# Weighted Threat Probabilities: {'CVE-2022-34878': 35.2, 'CVE-2022-35414': 52.800000000000004}

# %%
import requests
import json
import ipywidgets as widgets
from IPython.display import display

def fetch_cvss_scores(cve_ids):
    base_url = "https://services.nvd.nist.gov/rest/json/cve/1.0/"
    cvss_scores = {}

    for cve_id in cve_ids:
        url = f"{base_url}{cve_id}"
        response = requests.get(url)

        if response.status_code == 200:
            data = json.loads(response.text)
            cvss_v3 = data["result"]["CVE_Items"][0]["impact"]["baseMetricV3"]["cvssV3"]["baseScore"]
            cvss_scores[cve_id] = cvss_v3
        else:
            print(f"Error fetching data for {cve_id}")

    return cvss_scores

def calculate_threat_probability(cvss_scores, threat_frequencies):
    weighted_scores = {}
    for cve_id in cvss_scores:
        weighted_scores[cve_id] = cvss_scores[cve_id] * threat_frequencies[cve_id]

    return weighted_scores

def on_calculate_button_clicked(b):
    cve_ids = cve_input.value.split(",")
    threat_frequencies = {cve_id.strip(): freq_slider.value for cve_id in cve_ids}

    cvss_scores = fetch_cvss_scores(cve_ids)
    weighted_scores = calculate_threat_probability(cvss_scores, threat_frequencies)

    print("Weighted Threat Probabilities:")
    for cve_id, score in weighted_scores.items():
        print(f"{cve_id}: {score}")

# Create input widgets
cve_input = widgets.Text(
    placeholder="Enter CVE IDs separated by commas",
    description="CVE IDs:",
    layout=widgets.Layout(width="70%")
)

freq_slider = widgets.IntSlider(
    value=5,
    min=1,
    max=10,
    step=1,
    description="Frequency:",
    continuous_update=False
)

calculate_button = widgets.Button(
    description="Calculate",
    button_style="info",
    tooltip="Click to calculate threat probabilities"
)

# Display widgets
display(cve_input)
display(freq_slider)
display(calculate_button)

# Assign button click event
calculate_button.on_click(on_calculate_button_clicked)
# Out:
# Text(value='', description='CVE IDs:', layout=Layout(width='70%'), placeholder='Enter CVE IDs separated by com…
# IntSlider(value=5, continuous_update=False, description='Frequency:', max=10, min=1)
# Button(button_style='info', description='Calculate', style=ButtonStyle(), tooltip='Click to calculate threat p…
# Error fetching data for  CVE-2022-33948
# Error fetching data for  CVE-2022-26986
# Weighted Threat Probabilities:
# CVE-2022-34793: 61.60000000000001
# Weighted Threat Probabilities:
# CVE-2022-34793: 61.60000000000001
# Weighted Threat Probabilities:
# CVE-2022-34793: 26.400000000000002
# Weighted Threat Probabilities:
# CVE-2022-34793: 88.0
# Weighted Threat Probabilities:
# CVE-2022-30215: 75.0
# Weighted Threat Probabilities:
# CVE-2022-30215: 45.0
# Error fetching data for  CVE-2022-34793
# Error fetching data for
# Weighted Threat Probabilities:
# CVE-2022-30215: 45.0
# Error fetching data for  CVE-2022-34793
# Weighted Threat Probabilities:
# CVE-2022-30215: 45.0
# ...

# %%
import requests
import json
import ipywidgets as widgets
from IPython.display import display
import numpy as np
import skfuzzy as fuzz

def fetch_cvss_scores(cve_ids):
    base_url = "https://services.nvd.nist.gov/rest/json/cve/1.0/"
    cvss_scores = {}

    for cve_id in cve_ids:
        url = f"{base_url}{cve_id}"
        response = requests.get(url)

        if response.status_code == 200:
            data = json.loads(response.text)
            cvss_v3 = data["result"]["CVE_Items"][0]["impact"]["baseMetricV3"]["cvssV3"]["baseScore"]
            cvss_scores[cve_id] = cvss_v3
        else:
            print(f"Error fetching data for {cve_id}")

    return cvss_scores

def calculate_threat_probability(cvss_scores, threat_frequencies):
    weighted_scores = {}
    for cve_id in cvss_scores:
        weighted_scores[cve_id] = cvss_scores[cve_id] * threat_frequencies[cve_id]

    return weighted_scores

def fuzzy_categorize_threats(weighted_scores):
    x_score = np.arange(0, 101, 1)

    # Define fuzzy membership functions for Low, Medium, and High categories
    low = fuzz.trimf(x_score, [0, 0, 50])
    medium = fuzz.trimf(x_score, [0, 50, 100])
    high = fuzz.trimf(x_score, [50, 100, 100])

    categorized_threats = {}

    for cve_id, score in weighted_scores.items():
        low_category = fuzz.interp_membership(x_score, low, score)
        medium_category = fuzz.interp_membership(x_score, medium, score)
        high_category = fuzz.interp_membership(x_score, high, score)

        max_category = max(low_category, medium_category, high_category)

        if max_category == low_category:
            categorized_threats[cve_id] = ("Low", score)
        elif max_category == medium_category:
            categorized_threats[cve_id] = ("Medium", score)
        else:
            categorized_threats[cve_id] = ("High", score)

    return categorized_threats

def on_calculate_button_clicked(b):
    cve_ids = cve_input.value.split(",")
    threat_frequencies = {cve_id.strip(): freq_slider.value for cve_id in cve_ids}

    cvss_scores = fetch_cvss_scores(cve_ids)
    weighted_scores = calculate_threat_probability(cvss_scores, threat_frequencies)
    categorized_threats = fuzzy_categorize_threats(weighted_scores)

    print("Categorized Threat Probabilities:")
    for cve_id, (category, score) in categorized_threats.items():
        print(f"{cve_id}: {category} ({score:.2f})")

# Create input widgets
cve_input = widgets.Text(
    placeholder="Enter CVE IDs separated by commas",
    description="CVE IDs:",
    layout=widgets.Layout(width="70%")
)

freq_slider = widgets.IntSlider(
    value=5,
    min=1,
    max=10,
    step=1,
    description="Frequency:",
    continuous_update=False
)

calculate_button = widgets.Button(
description="Calculate",
button_style="info",
tooltip="Click to calculate threat probabilities"
)

# Display widgets
display(cve_input)
display(freq_slider)
display(calculate_button)

#Assign button click event
calculate_button.on_click(on_calculate_button_clicked)
# Out:
# Text(value='', description='CVE IDs:', layout=Layout(width='70%'), placeholder='Enter CVE IDs separated by com…
# IntSlider(value=5, continuous_update=False, description='Frequency:', max=10, min=1)
# Button(button_style='info', description='Calculate', style=ButtonStyle(), tooltip='Click to calculate threat p…
# Categorized Threat Probabilities:
# CVE-2022-32973: Medium (52.80)
# Categorized Threat Probabilities:
# CVE-2022-32973: Medium (61.60)
# Categorized Threat Probabilities:
# CVE-2022-32973: High (88.00)

# %%
import requests
import json
import ipywidgets as widgets
from IPython.display import display
import numpy as np
import skfuzzy as fuzz

def fetch_cvss_scores(cve_ids):
    base_url = "https://services.nvd.nist.gov/rest/json/cve/1.0/"
    cvss_scores = {}

    for cve_id in cve_ids:
        url = f"{base_url}{cve_id}"
        response = requests.get(url)

        if response.status_code == 200:
            data = json.loads(response.text)
            cvss_v3 = data["result"]["CVE_Items"][0]["impact"]["baseMetricV3"]["cvssV3"]["baseScore"]
            cvss_scores[cve_id] = cvss_v3
        else:
            print(f"Error fetching data for {cve_id}")

    return cvss_scores

def calculate_threat_probability(cvss_scores, threat_frequencies):
    weighted_scores = {}
    for cve_id in cvss_scores:
        weighted_scores[cve_id] = cvss_scores[cve_id] * threat_frequencies[cve_id]

    return weighted_scores

def fuzzy_categorize_threats(weighted_scores):
    x_score = np.arange(0, 101, 1)

    # Define fuzzy membership functions for Low, Medium, and High categories
    low = fuzz.trimf(x_score, [0, 0, 50])
    medium = fuzz.trimf(x_score, [0, 50, 100])
    high = fuzz.trimf(x_score, [50, 100, 100])

    categorized_threats = {}

    for cve_id, score in weighted_scores.items():
        low_category = fuzz.interp_membership(x_score, low, score)
        medium_category = fuzz.interp_membership(x_score, medium, score)
        high_category = fuzz.interp_membership(x_score, high, score)

        max_category = max(low_category, medium_category, high_category)

        if max_category == low_category:
            categorized_threats[cve_id] = ("Low", score)
        elif max_category == medium_category:
            categorized_threats[cve_id] = ("Medium", score)
        else:
            categorized_threats[cve_id] = ("High", score)

    return categorized_threats

def on_calculate_button_clicked(b):
    cve_ids = cve_input.value.split(",")
    threat_frequencies = {cve_id.strip(): freq_slider.value for cve_id in cve_ids}
    impact_scores = {cve_id.strip(): impact for cve_id, impact in zip(cve_ids, map(float, impact_input.value.split(",")))}

    cvss_scores = fetch_cvss_scores(cve_ids)
    weighted_scores = calculate_threat_probability(cvss_scores, threat_frequencies)
    categorized_threats = fuzzy_categorize_threats(weighted_scores)

    print("Categorized Threat Probabilities:")
    for cve_id, (category, score) in categorized_threats.items():
        print(f"{cve_id}: {category} ({score:.2f})")

    risks = {}
    for cve_id in cve_ids:
        impact = impact_scores[cve_id.strip()]
        likelihood = weighted_scores[cve_id.strip()]
        criticality = cvss_scores[cve_id.strip()]
        risk = impact * likelihood * criticality
        risks[cve_id.strip()] = risk

    print("Risks:")
    for cve_id, risk in risks.items():
        print(f"{cve_id}: {risk:.2f}")

# Create input widgets
cve_input = widgets.Text(
    placeholder="Enter CVE IDs separated by commas",
    description="CVE IDs:",
    layout=widgets.Layout(width="70%")
)

impact_input = widgets.Text(
    placeholder="Enter impact scores separated by commas",
    description="Impacts:",
    layout=widgets.Layout(width="70%")
)

freq_slider = widgets.IntSlider(
    value=5,
    min=1,
    max=10,
    step=1,
    description="Frequency:",
    continuous_update=False
)

calculate_button = widgets.Button(
    description="Calculate",
    button_style="info",
    tooltip="Click to calculate threat probabilities and risks"
)

# Display widgets
display(cve_input)
display(impact_input)
display(freq_slider)
display(calculate_button)

# Assign button click event
calculate_button.on_click(on_calculate_button_clicked)
# Out:
# Text(value='', description='CVE IDs:', layout=Layout(width='70%'), placeholder='Enter CVE IDs separated by com…
# Text(value='', description='Impacts:', layout=Layout(width='70%'), placeholder='Enter impact scores separated …
# IntSlider(value=5, continuous_update=False, description='Frequency:', max=10, min=1)
# Button(button_style='info', description='Calculate', style=ButtonStyle(), tooltip='Click to calculate threat p…
# Categorized Threat Probabilities:
# CVE-2022-31211: Medium (49.00)
# Risks:
# CVE-2022-31211: 2401.00

# %%
import requests
import json
import ipywidgets as widgets
from IPython.display import display
import numpy as np
import skfuzzy as fuzz

def fetch_cvss_scores(cve_ids):
    base_url = "https://services.nvd.nist.gov/rest/json/cve/1.0/"
    cvss_scores = {}

    for cve_id in cve_ids:
        url = f"{base_url}{cve_id}"
        response = requests.get(url)

        if response.status_code == 200:
            data = json.loads(response.text)
            cvss_v3 = data["result"]["CVE_Items"][0]["impact"]["baseMetricV3"]["cvssV3"]["baseScore"]
            cvss_scores[cve_id] = cvss_v3
        else:
            print(f"Error fetching data for {cve_id}")

    return cvss_scores

def normalize_score(score, old_range, new_range):
    old_min, old_max = old_range
    new_min, new_max = new_range
    return (((score - old_min) * (new_max - new_min)) / (old_max - old_min)) + new_min

def calculate_threat_probability(cvss_scores, threat_frequencies):
    weighted_scores = {}
    for cve_id in cvss_scores:
        weighted_scores[cve_id] = normalize_score(cvss_scores[cve_id], (0, 10), (1, 10)) * threat_frequencies[cve_id]

    return weighted_scores

def fuzzy_categorize_threats(weighted_scores):
    x_score = np.arange(0, 101, 1)

    # Define fuzzy membership functions for Low, Medium, and High categories
    low = fuzz.trimf(x_score, [0, 0, 50])
    medium = fuzz.trimf(x_score, [25, 50, 75])
    high = fuzz.trimf(x_score, [50, 100, 100])

    categorized_threats = {}

    for cve_id, score in weighted_scores.items():
        low_category = fuzz.interp_membership(x_score, low, score)
        medium_category = fuzz.interp_membership(x_score, medium, score)
        high_category = fuzz.interp_membership(x_score, high, score)

        max_category = max(low_category, medium_category, high_category)

        if max_category == low_category:
            categorized_threats[cve_id] = ("Low", score)
        elif max_category == medium_category:
            categorized_threats[cve_id] = ("Medium", score)
        else:
            categorized_threats[cve_id] = ("High", score)

    return categorized_threats


def fuzzy_risk(risk_score):
    x_risk = np.arange(0, 101, 1)

    # Define fuzzy membership functions for Low, Medium, and High risk categories
    low_risk = fuzz.trimf(x_risk, [0, 0, 50])
    medium_risk = fuzz.trimf(x_risk, [25, 50, 75])
    high_risk = fuzz.trimf(x_risk, [50, 100, 100])

    low_risk_category = fuzz.interp_membership(x_risk, low_risk, risk_score)
    medium_risk_category = fuzz.interp_membership(x_risk, medium_risk, risk_score)
    high_risk_category = fuzz.interp_membership(x_risk, high_risk, risk_score)

    max_category = max(low_risk_category, medium_risk_category, high_risk_category)

    if max_category == low_risk_category:
        return "Low"
    elif max_category == medium_risk_category:
        return "Medium"
    else:
        return "High"


def on_calculate_button_clicked(b):
    cve_ids = cve_input.value.split(",")
    threat_frequencies = {cve_id.strip(): freq_slider.value for cve_id in cve_ids}
    impact_scores = {cve_id.strip(): normalize_score(float(impact), (0, 10), (1, 10)) for cve_id, impact in zip(cve_ids, map(float, impact_input.value.split(",")))}

    cvss_scores = fetch_cvss_scores(cve_ids)
    weighted_scores = calculate_threat_probability(cvss_scores, threat_frequencies)
    categorized_threats = fuzzy_categorize_threats(weighted_scores)

    print("Categorized Threat Probabilities:")
    for cve_id, (category, score) in categorized_threats.items():
        print(f"{cve_id}: {category} ({score:.2f})")

    risks = {}
    for cve_id in cve_ids:
        impact = impact_scores[cve_id.strip()]
        likelihood = weighted_scores[cve_id.strip()]
        criticality = normalize_score(cvss_scores[cve_id.strip()], (0, 10), (1, 10))
        risk = normalize_score(impact * likelihood * criticality, (1, 1000), (1, 10))
        risks[cve_id.strip()] = risk

    print("Risks:")
    for cve_id, risk in risks.items():
        linguistic_risk = fuzzy_risk(risk)
        print(f"{cve_id}: {linguistic_risk} ({risk:.2f})")


# Create input widgets
cve_input = widgets.Text(
    placeholder="Enter CVE IDs separated by commas",
    description="CVE IDs:",
    layout=widgets.Layout(width="70%")
)

impact_input = widgets.Text(
    placeholder="Enter impact scores separated by commas",
    description="Impacts:",
    layout=widgets.Layout(width="70%")
)

freq_slider = widgets.IntSlider(
    value=5,
    min=1,
    max=10,
    step=1,
    description="Frequency:",
    continuous_update=False
)

calculate_button = widgets.Button(
    description="Calculate",
    button_style="info",
    tooltip="Click to calculate threat probabilities and risks"
)

# Display widgets
display(cve_input)
display(impact_input)
display(freq_slider)
display(calculate_button)

# Assign button click event
calculate_button.on_click(on_calculate_button_clicked)
# Out:
# Text(value='', description='CVE IDs:', layout=Layout(width='70%'), placeholder='Enter CVE IDs separated by com…
# Text(value='', description='Impacts:', layout=Layout(width='70%'), placeholder='Enter impact scores separated …
# IntSlider(value=5, continuous_update=False, description='Frequency:', max=10, min=1)
# Button(button_style='info', description='Calculate', style=ButtonStyle(), tooltip='Click to calculate threat p…
# Categorized Threat Probabilities:
# CVE-2022-32554: High (78.56)
# Risks:
# CVE-2022-32554: Medium (45.47)
# Categorized Threat Probabilities:
# CVE-2022-32554: High (88.38)
# Risks:
# CVE-2022-32554: High (72.14)
# Categorized Threat Probabilities:
# CVE-2022-32554: Low (29.46)
# Risks:
# CVE-2022-32554: Low (8.29)
